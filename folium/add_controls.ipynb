# %% [markdown]
# [DadosAbertosBrasil](https://www.gustavofurtado.com/DadosAbertosBrasil/_ibge/misc.html)
#
# [Folium](https://medium.com/datasciencearth/map-visualization-with-folium-d1403771717)
#
# [Folium and Geopandas: FeatureGroup for categorial data](https://www.riannek.de/2022/folium-featuregroup-categorial-data/)

# %%
from DadosAbertosBrasil import ibge
import pandas as pd

# %%
df_localidades = ibge.localidades()

# %%
df_localidades.columns
# Out:
# Index(['id', 'nome', 'municipio_id', 'municipio_nome', 'microrregiao_id',
#        'microrregiao_nome', 'mesorregiao_id', 'mesorregiao_nome', 'UF_id',
#        'UF_sigla', 'UF_nome', 'regiao_id', 'regiao_sigla', 'regiao_nome',
#        'regiao_imediata_id', 'regiao_imediata_nome', 'regiao_intermediaria_id',
#        'regiao_intermediaria_nome', 'UF_id', 'UF_sigla', 'UF_nome',
#        'regiao_id', 'regiao_sigla', 'regiao_nome'],
#       dtype='object')

# %%
df_localidades.head()
# Out:
#           id                 nome  municipio_id       municipio_nome  \
# 0  520005005      Abadia de Goiás       5200050      Abadia de Goiás
# 1  310010405  Abadia dos Dourados       3100104  Abadia dos Dourados
# 2  520010005            Abadiânia       5200100            Abadiânia
# 3  520010010       Posse d'Abadia       5200100            Abadiânia
# 4  310020305               Abaeté       3100203               Abaeté
#
#    microrregiao_id    microrregiao_nome  mesorregiao_id  \
# 0            52010              Goiânia            5203
# 1            31019           Patrocínio            3105
# 2            52012  Entorno de Brasília            5204
# 3            52012  Entorno de Brasília            5204
# 4            31024          Três Marias            3106
#
#                    mesorregiao_nome  UF_id UF_sigla  ... regiao_imediata_id  \
# 0                     Centro Goiano     52       GO  ...             520001
# 1  Triângulo Mineiro/Alto Paranaíba     31       MG  ...             310061
# 2                      Leste Goiano     52       GO  ...             520002
# 3                      Leste Goiano     52       GO  ...             520002
# 4                   Central Mineira     31       MG  ...             310070
#
#    regiao_imediata_nome regiao_intermediaria_id regiao_intermediaria_nome  \
# 0               Goiânia                    5201                   Goiânia
# 1         Monte Carmelo                    3111                Uberlândia
# 2              Anápolis                    5201                   Goiânia
# 3              Anápolis                    5201                   Goiânia
# 4                Abaeté                    3113               Divinópolis
#
#    UF_id UF_sigla       UF_nome regiao_id  regiao_sigla   regiao_nome
# 0     52       GO         Goiás         5            CO  Centro-Oeste
# 1     31       MG  Minas Gerais         3            SE       Sudeste
# 2     52       GO         Goiás         5            CO  Centro-Oeste
# 3     52       GO         Goiás         5            CO  Centro-Oeste
# 4     31       MG  Minas Gerais         3            SE       Sudeste
#
# [5 rows x 24 columns]

# %%
df_coordenadas = ibge.coordenadas()

# %%
df_coordenadas.columns
# Out:
# Index(['GM_PONTO', 'ID', 'CD_GEOCODIGO', 'TIPO', 'CD_GEOCODBA', 'NM_BAIRRO',
#        'CD_GEOCODSD', 'NM_SUBDISTRITO', 'CD_GEOCODDS', 'NM_DISTRITO',
#        'CD_GEOCODMU', 'NM_MUNICIPIO', 'NM_MICRO', 'NM_MESO', 'NM_UF',
#        'CD_NIVEL', 'CD_CATEGORIA', 'NM_CATEGORIA', 'NM_LOCALIDADE', 'LONG',
#        'LAT', 'ALT', 'GM_PONTO_sk'],
#       dtype='object')

# %%
pd.set_option('max.columns', None)
df_coordenadas.head()
# Out:
#    GM_PONTO  ID     CD_GEOCODIGO    TIPO   CD_GEOCODBA NM_BAIRRO  CD_GEOCODSD  \
# 0       NaN   1  110001505000001  URBANO  1.100015e+11   Redondo  11000150500
# 1       NaN   2  110001515000001  URBANO           NaN       NaN  11000151500
# 2       NaN   3  110001520000001  URBANO           NaN       NaN  11000152000
# 3       NaN   4  110001525000001  URBANO           NaN       NaN  11000152500
# 4       NaN   5  110001530000001  URBANO           NaN       NaN  11000153000
#
#   NM_SUBDISTRITO  CD_GEOCODDS                NM_DISTRITO  CD_GEOCODMU  \
# 0            NaN    110001505      ALTA FLORESTA D'OESTE      1100015
# 1            NaN    110001515         FILADÉLFIA D'OESTE      1100015
# 2            NaN    110001520                IZIDOLÂNDIA      1100015
# 3            NaN    110001525         NOVA GEASE D'OESTE      1100015
# 4            NaN    110001530  ROLIM DE MOURA DO GUAPORÉ      1100015
#
#             NM_MUNICIPIO NM_MICRO            NM_MESO     NM_UF  CD_NIVEL  \
# 0  ALTA FLORESTA D'OESTE   CACOAL  LESTE RONDONIENSE  RONDÔNIA         1
# 1  ALTA FLORESTA D'OESTE   CACOAL  LESTE RONDONIENSE  RONDÔNIA         2
# 2  ALTA FLORESTA D'OESTE   CACOAL  LESTE RONDONIENSE  RONDÔNIA         2
# 3  ALTA FLORESTA D'OESTE   CACOAL  LESTE RONDONIENSE  RONDÔNIA         2
# 4  ALTA FLORESTA D'OESTE   CACOAL  LESTE RONDONIENSE  RONDÔNIA         2
#
#    CD_CATEGORIA NM_CATEGORIA              NM_LOCALIDADE       LONG        LAT  \
# 0             5       CIDADE      ALTA FLORESTA D'OESTE -61.999824 -11.935540
# 1            15         VILA         FILADÉLFIA D'OESTE -62.043898 -12.437239
# 2            20         VILA                IZIDOLÂNDIA -62.175549 -12.601415
# 3            25         VILA         NOVA GEASE D'OESTE -62.318650 -11.919792
# 4            30         VILA  ROLIM DE MOURA DO GUAPORÉ -62.276812 -13.079806
#
#           ALT   GM_PONTO_sk
# 0  337.735719  1J6+^YP=gnhf
# 1  215.244429  1J6+gStX@d?>
# 2  181.044807  1J6+gwlc:Gtp
# 3  191.576571  1J6+^nhO?byf
# 4  157.285277  1J6+Hn4dy6Y-

# %%
df_LATLONG = df_coordenadas[['NM_MUNICIPIO', 'LONG', 'LAT']]

# %%
df_LATLONG
# Out:
#                 NM_MUNICIPIO       LONG        LAT
# 0      ALTA FLORESTA D'OESTE -61.999824 -11.935540
# 1      ALTA FLORESTA D'OESTE -62.043898 -12.437239
# 2      ALTA FLORESTA D'OESTE -62.175549 -12.601415
# 3      ALTA FLORESTA D'OESTE -62.318650 -11.919792
# 4      ALTA FLORESTA D'OESTE -62.276812 -13.079806
# ...                      ...        ...        ...
# 21881               BRASÍLIA -48.238160 -15.939671
# 21882               BRASÍLIA -48.228517 -15.936009
# 21883               BRASÍLIA -48.241670 -15.939968
# 21884               BRASÍLIA -48.222924 -15.939726
# 21885               BRASÍLIA -48.229109 -15.947606
#
# [21886 rows x 3 columns]

# %%
import folium
from folium import plugins
from folium.plugins import HeatMap

# %%
df_LATLONG.columns
# Out:
# Index(['NM_MUNICIPIO', 'LONG', 'LAT'], dtype='object')

# %%
df = df_LATLONG.sample(n=100)

# %% [markdown]
# # Exemplo 1 de Folium

# %%
mapc = folium.Map(location=[df_LATLONG.LAT.mean(), df_LATLONG.LONG.mean()], zoom_start=5, control_scale=True)

# Configuração de heatmap
heatmap = HeatMap(list(zip(df.LAT, df.LONG, df["LONG"]**10)),
               min_opacity=0.5,
               max_val=df["LONG"].max(),
               radius=50, blur=30, 
               max_zoom=1,
              control=True,
        )
# Cria camadas
layer1 = folium.FeatureGroup(name='Markers', control=True)
layer2 = folium.FeatureGroup(name='Circulos', control=True)
layer3 = folium.FeatureGroup(name='Heatmap', control=True)
for index, location_info in df.iterrows():

    # Adiciona propriedades às camadas
    layer1.add_child(folium.Marker([location_info["LAT"], location_info["LONG"]], popup=location_info["NM_MUNICIPIO"]))
    layer2.add_child(folium.CircleMarker([location_info["LAT"], location_info["LONG"]], radius=(abs(location_info["LAT"])), fill_color='blue', popup=location_info["NM_MUNICIPIO"]))


layer3.add_child(heatmap)

# Adiciona as camadas ao mapa
mapc.add_child(layer1)
mapc.add_child(layer2)
mapc.add_child(layer3)


# Adiciona o controle de camdas ao mapa
folium.LayerControl().add_to(mapc)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The `max_val` parameter is no longer necessary. The largest intensity is calculated automatically.
#   if __name__ == "__main__":

# %%
mapc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_103e5b7528784f18db23e6cd0d47b823 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_103e5b7528784f18db23e6cd0d47b823&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_103e5b7528784f18db23e6cd0d47b823 = L.map(
#                 &quot;map_103e5b7528784f18db23e6cd0d47b823&quot;,
#                 {
#                     center: [-14.067144574523127, -45.5448010707875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_103e5b7528784f18db23e6cd0d47b823);
#
#
#
#
#
#             var tile_layer_d72d4c54d0be5065626406a786eb240c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_103e5b7528784f18db23e6cd0d47b823);
#
#
#             var feature_group_f3d528f117bfddfffe052f1f5e29f607 = L.featureGroup(
#                 {}
#             ).addTo(map_103e5b7528784f18db23e6cd0d47b823);
#
#
#             var marker_82594c6b7eec8fdc1f31b1a89c984f4b = L.marker(
#                 [-22.5639412739458, -43.0524633983186],
#                 {}
#             ).addTo(feature_group_f3d528f117bfddfffe052f1f5e29f607);
#
#
#         var popup_0965b227a39914d2806c6fb15c5db2bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7bb36c3838b1c4139ebc51b771ac6997 = $(`&lt;div id=&quot;html_7bb36c3838b1c4139ebc51b771ac6997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MAGÉ&lt;/div&gt;`)[0];
#                 popup_0965b227a39914d2806c6fb15c5db2bd.setContent(html_7bb36c3838b1c4139ebc51b771ac6997);
#
#
#
#         marker_82594c6b7eec8fdc1f31b1a89c984f4b.bindPopup(popup_0965b227a39914d2806c6fb15c5db2bd)
#         ;
#
#
#
#
#             var marker_e0cc2988fdde78b82d9acd1b126eefa4 = L.marker(
#                 [-29.416865849997, -49.9530829034207],
#                 {}
#             ).addTo(feature_group_f3d528f117bfddfffe052f1f5e29f607);
#
#
#         var popup_b0226fbd74e2781d731818231b9148b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42aea63a334d3ed495981ddc29e47ce1 = $(`&lt;div id=&quot;html_42aea63a334d3ed495981ddc29e47ce1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TRÊS CACHOEIRAS&lt;/div&gt;`)[0];
#                 popup_b0226fbd74e2781d731818231b9148b6.setContent(html_42aea63a334d3ed495981ddc29e47ce1);
#
#
#
#         marker_e0cc2988fdde78b82d9acd1b126eefa4.bindPopup(popup_b0226fbd74e2781d731818231b9148b6)
#         ;
#
#
#
#
#             var marker_5c1116a570302258f089941ffba66ef2 = L.marker(
#                 [-13.5105518394762, -39.45094216111],
#                 {}
#             ).addTo(feature_group_f3d528f117bfddfffe052f1f5e29f607);
#
#
#         var popup_96704db6358924c022a862b87d095d31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_891ea2dc721ca43846e8f4317c4985c7 = $(`&lt;div id=&quot;html_891ea2dc721ca43846e8f4317c4985c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PRESIDENTE TANCREDO NEVES&lt;/div&gt;`)[0];
#                 popup_96704db6358924c022a862b87d095d31.setContent(html_891ea2dc721ca43846e8f4317c4985c7);
#
#
#
#         marker_5c1116a570302258f089941ffba66ef2.bindPopup(popup_96704db6358924c022a862b87d095d31)
#         ;
#
#
#
#
#             var marker_ccb9968041e9bb17f77c359ac46a8dd4 = L.marker(
#                 [-1.983116, -48.9622994689466],
#                 {}
#             ).addTo(feature_group_f3d528f117bfddfffe052f1f5e29f607);
#
#
#         var popup_7e78f743218e6b802402a0c34fa7896c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9de7cc68ccbbbbfca115aeeb94967375 = $(`&lt;div id=&quot;html_9de7cc68ccbbbbfca115aeeb94967375&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IGARAPÉ-MIRI&lt;/div&gt;`)[0];
#                 popup_7e78f743218e6b802402a0c34fa7896c.setContent(html_9de7cc68ccbbbbfca115aeeb94967375);
#
#
#
#         marker_ccb9968041e9bb17f77c359ac46a8dd4.bindPopup(popup_7e78f743218e6b802402a0c34fa7896c)
#         ;
#
#
#
#
#             var marker_0592f21c7ef82bbe5ff86c61453ebeff = L.marker(
#                 [-28.9985764275982, -51.6964336774026],
#                 {}
#             ).addTo(feature_group_f3d528f117bfddfffe052f1f5e29f607);
#
#
#         var popup_1aa1a3d3e9b8f5c667b0ab89aa997c75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a42f3b42880db796fc77bb0c5b50

# %%
mapc.save("mapa_camadas.html")
